# %% [markdown]
# ## Creating Heatmap for the Busiest Airports in The world

# %% [markdown]
# ### Scrape data from wikipedia using scrapy

# %%
import scrapy
import csv
from scrapy.crawler import CrawlerProcess
from scrapy import Request





class BusyAirportSpider(scrapy.Spider):
    name = 'busy_airport'
    allowed_domains = ['en.wikipedia.org']
    start_urls = ['https://en.wikipedia.org/wiki/List_of_busiest_airports_by_passenger_traffic']

    
    def parse(self, response):
        country = response.xpath('//*[@id="mw-content-text"]/div/table[1]/tbody/tr/td/span/a/@title').extract()
        airport =  response.xpath('//*[@id="mw-content-text"]/div/table[1]/tbody/tr/td[2]/a/@title').extract()
        location = response.xpath('//*[@id="mw-content-text"]/div/table[2]/tbody/tr/td[3]/a[1]/text()').extract()
        no_of_passengers = response.xpath('//*[@id="mw-content-text"]/div/table[2]/tbody/tr/td[6]/text()').extract()
        for i in range(len(response.xpath('//*[@id="mw-content-text"]/div/table[1]/tbody/tr/td[2]/a/@title').extract())):
            yield {'Country':country[i],'Airport':airport[i],'location':location[i],'no_of_passengers':no_of_passengers[i]}

# %%
process = CrawlerProcess({'FEED_URI': 'Busy_airport.csv','FEED_FORMAT': 'csv'})
process.crawl(BusyAirportSpider)
process.start()
# Out:
# 2020-06-15 17:26:06 [scrapy.utils.log] INFO: Scrapy 1.4.0 started (bot: scrapybot)
# 2020-06-15 17:26:06 [scrapy.utils.log] INFO: Overridden settings: {'FEED_FORMAT': 'csv', 'FEED_URI': 'Busy_airport.csv'}
# 2020-06-15 17:26:06 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2020-06-15 17:26:06 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2020-06-15 17:26:06 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2020-06-15 17:26:06 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2020-06-15 17:26:06 [scrapy.core.engine] INFO: Spider opened
# 2020-06-15 17:26:06 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2020-06-15 17:26:06 [scrapy.extensions.telnet] DEBUG: Telnet console listening on 127.0.0.1:6023
# 2020-06-15 17:26:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://en.wikipedia.org/wiki/List_of_busiest_airports_by_passenger_traffic> (referer: None)
# 2020-06-15 17:26:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_busiest_airports_by_passenger_traffic>
# {'Country': 'United States', 'Airport': 'Hartsfield–Jackson Atlanta International Airport', 'location': 'Atlanta', 'no_of_passengers': '107,394,029'}
# 2020-06-15 17:26:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_busiest_airports_by_passenger_traffic>
# {'Country': 'China', 'Airport': 'Beijing Capital International Airport', 'location': 'Chaoyang', 'no_of_passengers': '100,983,290'}
# 2020-06-15 17:26:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_busiest_airports_by_passenger_traffic>
# {'Country': 'United States', 'Airport': 'Los Angeles International Airport', 'location': 'Garhoud', 'no_of_passengers': '89,149,387'}
# 2020-06-15 17:26:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_busiest_airports_by_passenger_traffic>
# {'Country': 'Japan', 'Airport': 'Haneda Airport', 'location': 'Los Angeles', 'no_of_passengers': '87,534,384'}
# 2020-06-15 17:26:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_busiest_airports_by_passenger_traffic>
# {'Country': 'United Arab Emirates', 'Airport': 'Dubai International Airport', 'location': 'Ōta', 'no_of_passengers': '87,131,973'}
# 2020-06-15 17:26:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_busiest_airports_by_passenger_traffic>
# {'Country': 'United States', 'Airport': "O'Hare International Airport", 'location': 'Chicago', 'no_of_passengers': '83,339,186'}
# 2020-06-15 17:26:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_busiest_airports_by_passenger_traffic>
# {'Country': 'United Kingdom', 'Airport': 'London Heathrow Airport', 'location': 'Hillingdon', 'no_of_passengers': '80,126,320'}
# 2020-06-15 17:26:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_busiest_airports_by_passenger_traffic>
# {'Country': 'China', 'Airport': 'Shanghai Pudong International Airport', 'location': 'Chek Lap Kok', 'no_of_passengers': '74,517,402'}
# 2020-06-15 17:26:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_busiest_airports_by_passenger_traffic>
# {'Country': 'France', 'Airport': 'Charles de Gaulle Airport', 'location': 'Pudong', 'no_of_passengers': '74,006,331'}
# 2020-06-15 17:26:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_busiest_airports_by_passenger_traffic>
# {'Country': 'United States', 'Airport': 'Dallas/Fort Worth International Airport', 'location': 'Roissy-en-France', 'no_of_passengers': '72,229,723'}
# 2020-06-15 17:26:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_busiest_airports_by_passenger_traffic>
# {'Country': 'China', 'Airport': 'Guangzhou Baiyun International Airport', 'location': 'Haarlemmermeer', 'no_of_passengers': '71,053,157'}
# 2020-06-15 17:26:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_busiest_airports_by_passenger_traffic>
# {'Country': 'Netherlands', 'Airport': 'Amsterdam Airport Schiphol', 'location': 'Delhi', 'no_of_passengers': '69,900,938'}
# 2020-06-15 17:26:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_busiest_airports_by_passenger_traffic>
# {'Country': 'Hong Kong', 'Airport': 'Hong Kong International Airport', 'location': 'Baiyun', 'no_of_passengers': '69,769,497'}
# 2020-06-15 17:26:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_busiest_airports_by_passenger_traffic>
# {'Country': 'Germany', 'Airport': 'Frankfurt Airport', 'location': 'Frankfurt', 'no_of_passengers': '69,510,269'}
# 2020-06-15 17:26:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_busiest_airports_by_passenger_traffic>
# {'Country': 'United States', 'Airport': 'Denver International Airport', 'location': 'Dallas', 'no_of_passengers': '69,112,607'}
# 2020-06-15 17:26:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_busiest_airports_by_passenger_traffic>
# {'Country': 'South Korea', 'Airport': 'Seoul Incheon International Airport', 'location': 'Incheon', 'no_of_passengers': '68,350,784'}
# 2020-06-15 17:26:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_busiest_airports_by_passenger_traffic>
# {'Country': 'Singapore', 'Airport': 'Singapore Changi Airport', 'location': 'Yeşilköy', 'no_of_passengers': '68,192,683'}
# 2020-06-15 17:26:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_busiest_airports_by_passenger_traffic>
# {'Country': 'India', 'Airport': 'Indira Gandhi International Airport', 'location': 'Tangerang', 'no_of_passengers': '66,908,159'}
# 2020-06-15 17:26:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_busiest_airports_by_passenger_traffic>
# {'Country': 'Thailand', 'Airport': 'Suvarnabhumi Airport', 'location': 'Changi', 'no_of_passengers': '65,628,000'}
# 2020-06-15 17:26:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_busiest_airports_by_passenger_traffic>
# {'Country': 'Indonesia', 'Airport': 'Soekarno–Hatta International Airport', 'location': 'Denver', 'no_of_passengers': '64,494,613'}
# 2020-06-15 17:26:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_busiest_airports_by_passenger_traffic>
# {'Country': 'United States', 'Airport': 'John F. Kennedy International Airport', 'location': 'Bang Phli', 'no_of_passengers': '63,378,923'}
# 2020-06-15 17:26:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_busiest_airports_by_passenger_traffic>
# {'Country': 'Malaysia', 'Airport': 'Kuala Lumpur International Airport', 'location': 'Queens', 'no_of_passengers': '61,909,148'}
# 2020-06-15 17:26:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_busiest_airports_by_passenger_traffic>
# {'Country': 'Spain', 'Airport': 'Madrid Barajas Airport', 'location': 'Sepang', 'no_of_passengers': '59,959,000'}
# 2020-06-15 17:26:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_busiest_airports_by_passenger_traffic>
# {'Country': 'United States', 'Airport': 'San Francisco International Airport', 'location': 'Barajas', 'no_of_passengers': '57,891,340'}
# 2020-06-15 17:26:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_busiest_airports_by_passenger_traffic>
# {'Country': 'China', 'Airport': 'Chengdu Shuangliu International Airport', 'location': 'San Mateo County', 'no_of_passengers': '57,793,313'}
# 2020-06-15 17:26:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_busiest_airports_by_passenger_traffic>
# {'Country': 'China', 'Airport': "Shenzhen Bao'an International Airport", 'location': 'Shuangliu', 'no_of_passengers': '52,950,000'}
# 2020-06-15 17:26:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_busiest_airports_by_passenger_traffic>
# {'Country': 'Spain', 'Airport': 'Barcelona–El Prat Airport', 'location': 'Barcelona', 'no_of_passengers': '50,172,457'}
# 2020-06-15 17:26:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_busiest_airports_by_passenger_traffic>
# {'Country': 'Turkey', 'Airport': 'Istanbul Airport', 'location': 'Mumbai', 'no_of_passengers': '49,877,918'}
# 2020-06-15 17:26:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_busiest_airports_by_passenger_traffic>
# {'Country': 'United States', 'Airport': 'Seattle-Tacoma International Airport', 'location': 'SeaTac', 'no_of_passengers': '49,849,520'}
# 2020-06-15 17:26:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_busiest_airports_by_passenger_traffic>
# {'Country': 'United States', 'Airport': 'McCarran International Airport', 'location': 'Las Vegas', 'no_of_passengers': '49,716,584'}
# 2020-06-15 17:26:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_busiest_airports_by_passenger_traffic>
# {'Country': 'United States', 'Airport': 'Orlando International Airport', 'location': 'Mississauga', 'no_of_passengers': '49,507,418'}
# 2020-06-15 17:26:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_busiest_airports_by_passenger_traffic>
# {'Country': 'Canada', 'Airport': 'Toronto Pearson International Airport', 'location': "Bao'an", 'no_of_passengers': '49,350,000'}
# 2020-06-15 17:26:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_busiest_airports_by_passenger_traffic>
# {'Country': 'Mexico', 'Airport': 'Benito Juárez International Airport', 'location': 'Venustiano Carranza', 'no_of_passengers': '47,700,547'}
# 2020-06-15 17:26:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_busiest_airports_by_passenger_traffic>
# {'Country': 'United States', 'Airport': 'Charlotte Douglas International Airport', 'location': 'Orlando', 'no_of_passengers': '47,696,627'}
# 2020-06-15 17:26:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_busiest_airports_by_passenger_traffic>
# {'Country': 'India', 'Airport': 'Chhatrapati Shivaji Maharaj International Airport', 'location': 'Guandu', 'no_of_passengers': '47,090,000'}
# 2020-06-15 17:26:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_busiest_airports_by_passenger_traffic>
# {'Country': 'Taiwan', 'Airport': 'Taiwan Taoyuan International Airport', 'location': 'Dayuan', 'no_of_passengers': '46,535,180'}
# 2020-06-15 17:26:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_busiest_airports_by_passenger_traffic>
# {'Country': 'China', 'Airport': 'Kunming Changshui International Airport', 'location': 'Charlotte', 'no_of_passengers': '46,444,380'}
# 2020-06-15 17:26:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_busiest_airports_by_passenger_traffic>
# {'Country': 'Germany', 'Airport': 'Munich Airport', 'location': 'Freising', 'no_of_passengers': '46,253,623'}
# 2020-06-15 17:26:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_busiest_airports_by_passenger_traffic>
# {'Country': 'Philippines', 'Airport': 'Ninoy Aquino International Airport', 'location': 'Crawley', 'no_of_passengers': '46,075,400'}
# 2020-06-15 17:26:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_busiest_airports_by_passenger_traffic>
# {'Country': 'China', 'Airport': "Xi'an Xianyang International Airport", 'location': 'Newark', 'no_of_passengers': '46,065,175'}
# 2020-06-15 17:26:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_busiest_airports_by_passenger_traffic>
# {'Country': 'United Kingdom', 'Airport': 'London Gatwick Airport', 'location': 'Khimki', 'no_of_passengers': '45,836,000'}
# 2020-06-15 17:26:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_busiest_airports_by_passenger_traffic>
# {'Country': 'United States', 'Airport': 'Newark Liberty International Airport', 'location': 'Pasay', 'no_of_passengers': '45,082,544'}
# 2020-06-15 17:26:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_busiest_airports_by_passenger_traffic>
# {'Country': 'United States', 'Airport': 'Phoenix Sky Harbor International Airport', 'location': 'Miami-Dade County', 'no_of_passengers': '45,044,312'}
# 2020-06-15 17:26:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_busiest_airports_by_passenger_traffic>
# {'Country': 'Russia', 'Airport': 'Sheremetyevo International Airport', 'location': 'Phoenix', 'no_of_passengers': '44,943,686'}
# 2020-06-15 17:26:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_busiest_airports_by_passenger_traffic>
# {'Country': 'United States', 'Airport': 'Miami International Airport', 'location': 'Weicheng', 'no_of_passengers': '44,653,311'}
# 2020-06-15 17:26:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_busiest_airports_by_passenger_traffic>
# {'Country': 'China', 'Airport': 'Shanghai Hongqiao International Airport', 'location': 'Mascot', 'no_of_passengers': '44,389,000'}
# 2020-06-15 17:26:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_busiest_airports_by_passenger_traffic>
# {'Country': 'United States', 'Airport': 'George Bush Intercontinental Airport', 'location': 'Houston', 'no_of_passengers': '43,807,539'}
# 2020-06-15 17:26:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_busiest_airports_by_passenger_traffic>
# {'Country': 'China', 'Airport': 'Chongqing Jiangbei International Airport', 'location': 'Changning', 'no_of_passengers': '43,630,000'}
# 2020-06-15 17:26:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_busiest_airports_by_passenger_traffic>
# {'Country': 'Australia', 'Airport': 'Sydney Airport', 'location': 'Rome', 'no_of_passengers': '42,995,119'}
# 2020-06-15 17:26:07 [scrapy.core.scraper] DEBUG: Scraped from <200 https://en.wikipedia.org/wiki/List_of_busiest_airports_by_passenger_traffic>
# {'Country': 'Italy', 'Airport': 'Leonardo da Vinci–Fiumicino Airport', 'location': 'Guarulhos', 'no_of_passengers': '42,831,981'}
# 2020-06-15 17:26:07 [scrapy.core.engine] INFO: Closing spider (finished)
# 2020-06-15 17:26:07 [scrapy.extensions.feedexport] INFO: Stored csv feed (50 items) in: Busy_airport.csv
# 2020-06-15 17:26:07 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 264,
#  'downloader/request_count': 1,
#  'downloader/request_method_count/GET': 1,
#  'downloader/response_bytes': 85073,
#  'downloader/response_count': 1,
#  'downloader/response_status_count/200': 1,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2020, 6, 15, 15, 26, 7, 426220),
#  'item_scraped_count': 50,
#  'log_count/DEBUG': 52,
#  'log_count/INFO': 8,
#  'memusage/max': 72028160,
#  'memusage/startup': 72028160,
#  'response_received_count': 1,
#  'scheduler/dequeued': 1,
#  'scheduler/dequeued/memory': 1,
#  'scheduler/enqueued': 1,
#  'scheduler/enqueued/memory': 1,
#  'start_time': datetime.datetime(2020, 6, 15, 15, 26, 6, 206237)}
# 2020-06-15 17:26:07 [scrapy.core.engine] INFO: Spider closed (finished)

# %%
#load the data using pandas
import pandas as pd
df3 = pd.read_csv('Busy_airport.csv')

# %%
df3.head()
# Out:
#                 Country                                           Airport  \
# 0         United States  Hartsfield–Jackson Atlanta International Airport
# 1                 China             Beijing Capital International Airport
# 2         United States                 Los Angeles International Airport
# 3                 Japan                                    Haneda Airport
# 4  United Arab Emirates                       Dubai International Airport
#
#       location no_of_passengers
# 0      Atlanta      107,394,029
# 1     Chaoyang      100,983,290
# 2      Garhoud       89,149,387
# 3  Los Angeles       87,534,384
# 4          Ōta       87,131,973

# %%
df3.shape
# Out:
# (50, 4)

# %%
df3.info
# Out:
# <bound method DataFrame.info of                  Country                                            Airport  \
# 0          United States   Hartsfield–Jackson Atlanta International Airport
# 1                  China              Beijing Capital International Airport
# 2          United States                  Los Angeles International Airport
# 3                  Japan                                     Haneda Airport
# 4   United Arab Emirates                        Dubai International Airport
# 5          United States                       O'Hare International Airport
# 6         United Kingdom                            London Heathrow Airport
# 7                  China              Shanghai Pudong International Airport
# 8                 France                          Charles de Gaulle Airport
# 9          United States            Dallas/Fort Worth International Airport
# 10                 China             Guangzhou Baiyun International Airport
# 11           Netherlands                         Amsterdam Airport Schiphol
# 12             Hong Kong                    Hong Kong International Airport
# 13               Germany                                  Frankfurt Airport
# 14         United States                       Denver International Airport
# 15           South Korea                Seoul Incheon International Airport
# 16             Singapore                           Singapore Changi Airport
# 17                 India                Indira Gandhi International Airport
# 18              Thailand                               Suvarnabhumi Airport
# 19             Indonesia               Soekarno–Hatta International Airport
# 20         United States              John F. Kennedy International Airport
# 21              Malaysia                 Kuala Lumpur International Airport
# 22                 Spain                             Madrid Barajas Airport
# 23         United States                San Francisco International Airport
# 24                 China            Chengdu Shuangliu International Airport
# 25                 China              Shenzhen Bao'an International Airport
# 26                 Spain                          Barcelona–El Prat Airport
# 27                Turkey                                   Istanbul Airport
# 28         United States               Seattle-Tacoma International Airport
# 29         United States                     McCarran International Airport
# 30         United States                      Orlando International Airport
# 31                Canada              Toronto Pearson International Airport
# 32                Mexico                Benito Juárez International Airport
# 33         United States            Charlotte Douglas International Airport
# 34                 India  Chhatrapati Shivaji Maharaj International Airport
# 35                Taiwan               Taiwan Taoyuan International Airport
# 36                 China            Kunming Changshui International Airport
# 37               Germany                                     Munich Airport
# 38           Philippines                 Ninoy Aquino International Airport
# 39                 China               Xi'an Xianyang International Airport
# 40        United Kingdom                             London Gatwick Airport
# 41         United States               Newark Liberty International Airport
# 42         United States           Phoenix Sky Harbor International Airport
# 43                Russia                 Sheremetyevo International Airport
# 44         United States                        Miami International Airport
# 45                 China            Shanghai Hongqiao International Airport
# 46         United States               George Bush Intercontinental Airport
# 47                 China           Chongqing Jiangbei International Airport
# 48             Australia                                     Sydney Airport
# 49                 Italy                Leonardo da Vinci–Fiumicino Airport
#
#                location no_of_passengers
# 0               Atlanta      107,394,029
# 1              Chaoyang      100,983,290
# 2               Garhoud       89,149,387
# 3           Los Angeles       87,534,384
# 4                   Ōta       87,131,973
# 5               Chicago       83,339,186
# 6            Hillingdon       80,126,320
# 7          Chek Lap Kok       74,517,402
# 8                Pudong       74,006,331
# 9      Roissy-en-France       72,229,723
# 10       Haarlemmermeer       71,053,157
# 11                Delhi       69,900,938
# 12               Baiyun       69,769,497
# 13            Frankfurt       69,510,269
# 14               Dallas       69,112,607
# 15              Incheon       68,350,784
# 16             Yeşilköy       68,192,683
# 17            Tangerang       66,908,159
# 18               Changi       65,628,000
# 19               Denver       64,494,613
# 20            Bang Phli       63,378,923
# 21               Queens       61,909,148
# 22               Sepang       59,959,000
# 23              Barajas       57,891,340
# 24     San Mateo County       57,793,313
# 25            Shuangliu       52,950,000
# 26            Barcelona       50,172,457
# 27               Mumbai       49,877,918
# 28               SeaTac       49,849,520
# 29            Las Vegas       49,716,584
# 30          Mississauga       49,507,418
# 31               Bao'an       49,350,000
# 32  Venustiano Carranza       47,700,547
# 33              Orlando       47,696,627
# 34               Guandu       47,090,000
# 35               Dayuan       46,535,180
# 36            Charlotte       46,444,380
# 37             Freising       46,253,623
# 38              Crawley       46,075,400
# 39               Newark       46,065,175
# 40               Khimki       45,836,000
# 41                Pasay       45,082,544
# 42    Miami-Dade County       45,044,312
# 43              Phoenix       44,943,686
# 44             Weicheng       44,653,311
# 45               Mascot       44,389,000
# 46              Houston       43,807,539
# 47            Changning       43,630,000
# 48                 Rome       42,995,119
# 49            Guarulhos       42,831,981  >

# %%
import numpy as np
# Create a empty Column to insert lattitude and longitude values of the aiport locations
df3['lat'] = np.nan
df3['lon'] = np.nan

# %%
#Using Geocoder we get the lattitude and longitude values of the airport locations
#! pip install geocoder
import geocoder
#to show the progress of the process
from tqdm import tqdm

for i in tqdm(range(df3.shape[0])):
    co_ord = geocoder.osm(('{s}').format(s = df3['Airport'][i]))
    if co_ord.lat and co_ord.lng  != np.nan:
        df3['lat'][i] = co_ord.lat
        df3['lon'][i] = co_ord.lng
    else: 
        co_ord = geocoder.osm(('{l}').format(l = df3['Country'][i]))
        df3['lat'][i] = co_ord.lat
        df3['lon'][i] = co_ord.lng
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]2020-06-15 17:26:17 [urllib3.connectionpool] DEBUG: Starting new HTTPS connection (1): nominatim.openstreetmap.org:443
# 2020-06-15 17:26:18 [urllib3.connectionpool] DEBUG: https://nominatim.openstreetmap.org:443 "GET /search?q=Hartsfield%E2%80%93Jackson+Atlanta+International+Airport&format=jsonv2&addressdetails=1&limit=1 HTTP/1.1" 200 None
# 2020-06-15 17:26:18 [geocoder.base] INFO: Requested https://nominatim.openstreetmap.org/search?q=Hartsfield%E2%80%93Jackson+Atlanta+International+Airport&format=jsonv2&addressdetails=1&limit=1
# 2020-06-15 17:26:18 [py.warnings] WARNING: /Users/raghulkrishna/opt/anaconda3/envs/scrapy/lib/python3.6/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
#
# 2020-06-15 17:26:18 [py.warnings] WARNING: /Users/raghulkrishna/opt/anaconda3/envs/scrapy/lib/python3.6/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
#
#   2%|▏         | 1/50 [00:00<00:09,  5.01it/s]2020-06-15 17:26:18 [urllib3.connectionpool] DEBUG: Starting new HTTPS connection (1): nominatim.openstreetmap.org:443
# 2020-06-15 17:26:18 [urllib3.connectionpool] DEBUG: https://nominatim.openstreetmap.org:443 "GET /search?q=Beijing+Capital+International+Airport&format=jsonv2&addressdetails=1&limit=1 HTTP/1.1" 200 None
# 2020-06-15 17:26:18 [geocoder.base] INFO: Requested https://nominatim.openstreetmap.org/search?q=Beijing+Capital+International+Airport&format=jsonv2&addressdetails=1&limit=1
#   4%|▍         | 2/50 [00:00<00:14,  3.38it/s]2020-06-15 17:26:18 [urllib3.connectionpool] DEBUG: Starting new HTTPS connection (1): nominatim.openstreetmap.org:443
# 2020-06-15 17:26:19 [urllib3.connectionpool] DEBUG: https://nominatim.openstreetmap.org:443 "GET /search?q=Los+Angeles+International+Airport&format=jsonv2&addressdetails=1&limit=1 HTTP/1.1" 200 None
# 2020-06-15 17:26:19 [geocoder.base] INFO: Requested https://nominatim.openstreetmap.org/search?q=Los+Angeles+International+Airport&format=jsonv2&addressdetails=1&limit=1
#   6%|▌         | 3/50 [00:01<00:17,  2.71it/s]2020-06-15 17:26:19 [urllib3.connectionpool] DEBUG: Starting new HTTPS connection (1): nominatim.openstreetmap.org:443
# 2020-06-15 17:26:19 [urllib3.connectionpool] DEBUG: https://nominatim.openstreetmap.org:443 "GET /search?q=Haneda+Airport&format=jsonv2&addressdetails=1&limit=1 HTTP/1.1" 200 None
# 2020-06-15 17:26:19 [geocoder.base] INFO: Requested https://nominatim.openstreetmap.org/search?q=Haneda+Airport&format=jsonv2&addressdetails=1&limit=1
#   8%|▊         | 4/50 [00:01<00:18,  2.47it/s]2020-06-15 17:26:19 [urllib3.connectionpool] DEBUG: Starting new HTTPS connection (1): nominatim.openstreetmap.org:443
# 2020-06-15 17:26:20 [urllib3.connectionpool] DEBUG: https://nominatim.openstreetmap.org:443 "GET /search?q=Dubai+International+Airport&format=jsonv2&addressdetails=1&limit=1 HTTP/1.1" 200 None
# 2020-06-15 17:26:20 [geocoder.base] INFO: Requested https://nominatim.openstreetmap.org/search?q=Dubai+International+Airport&format=jsonv2&addressdetails=1&limit=1
#  10%|█         | 5/50 [00:02<00:19,  2.29it/s]2020-06-15 17:26:20 [urllib3.connectionpool] DEBUG: Starting new HTTPS connection (1): nominatim.openstreetmap.org:443
# 2020-06-15 17:26:20 [urllib3.connectionpool] DEBUG: https://nominatim.openstreetmap.org:443 "GET /search?q=O%27Hare+International+Airport&format=jsonv2&addressdetails=1&limit=1 HTTP/1.1" 200 None
# 2020-06-15 17:26:20 [geocoder.base] INFO: Requested https://nominatim.openstreetmap.org/search?q=O%27Hare+International+Airport&format=jsonv2&addressdetails=1&limit=1
#  12%|█▏        | 6/50 [00:02<00:20,  2.18it/s]2020-06-15 17:26:20 [urllib3.connectionpool] DEBUG: Starting new HTTPS connection (1): nominatim.openstreetmap.org:443
# 2020-06-15 17:26:21 [urllib3.connectionpool] DEBUG: https://nominatim.openstreetmap.org:443 "GET /search?q=London+Heathrow+Airport&format=jsonv2&addressdetails=1&limit=1 HTTP/1.1" 200 None
# 2020-06-15 17:26:21 [geocoder.base] INFO: Requested https://nominatim.openstreetmap.org/search?q=London+Heathrow+Airport&format=jsonv2&addressdetails=1&limit=1
#  14%|█▍        | 7/50 [00:03<00:20,  2.10it/s]2020-06-15 17:26:21 [urllib3.connectionpool] DEBUG: Starting new HTTPS connection (1): nominatim.openstreetmap.org:443
# 2020-06-15 17:26:21 [urllib3.connectionpool] DEBUG: https://nominatim.openstreetmap.org:443 "GET /search?q=Shanghai+Pudong+International+Airport&format=jsonv2&addressdetails=1&limit=1 HTTP/1.1" 200 None
# 2020-06-15 17:26:21 [geocoder.base] INFO: Requested https://nominatim.openstreetmap.org/search?q=Shanghai+Pudong+International+Airport&format=jsonv2&addressdetails=1&limit=1
#  16%|█▌        | 8/50 [00:03<00:20,  2.06it/s]2020-06-15 17:26:21 [urllib3.connectionpool] DEBUG: Starting new HTTPS connection (1): nominatim.openstreetmap.org:443
# 2020-06-15 17:26:22 [urllib3.connectionpool] DEBUG: https://nominatim.openstreetmap.org:443 "GET /search?q=Charles+de+Gaulle+Airport&format=jsonv2&addressdetails=1&limit=1 HTTP/1.1" 200 None
# 2020-06-15 17:26:22 [geocoder.base] INFO: Requested https://nominatim.openstreetmap.org/search?q=Charles+de+Gaulle+Airport&format=jsonv2&addressdetails=1&limit=1
#  18%|█▊        | 9/50 [00:04<00:18,  2.18it/s]2020-06-15 17:26:22 [urllib3.connectionpool] DEBUG: Starting new HTTPS connection (1): nominatim.openstreetmap.org:443
# 2020-06-15 17:26:22 [urllib3.connectionpool] DEBUG: https://nominatim.openstreetmap.org:443 "GET /search?q=Dallas%2FFort+Worth+International+Airport&format=jsonv2&addressdetails=1&limit=1 HTTP/1.1" 200 None
# 2020-06-15 17:26:22 [geocoder.base] INFO: Requested https://nominatim.openstreetmap.org/search?q=Dallas%2FFort+Worth+International+Airport&format=jsonv2&addressdetails=1&limit=1
#  20%|██        | 10/50 [00:04<00:19,  2.09it/s]2020-06-15 17:26:22 [urllib3.connectionpool] DEBUG: Starting new HTTPS connection (1): nominatim.openstreetmap.org:443
# 2020-06-15 17:26:23 [urllib3.connectionpool] DEBUG: https://nominatim.openstreetmap.org:443 "GET /search?q=Guangzhou+Baiyun+International+Airport&format=jsonv2&addressdetails=1&limit=1 HTTP/1.1" 200 None
# 2020-06-15 17:26:23 [geocoder.base] INFO: Requested https://nominatim.openstreetmap.org/search?q=Guangzhou+Baiyun+International+Airport&format=jsonv2&addressdetails=1&limit=1
#  22%|██▏       | 11/50 [00:05<00:19,  2.05it/s]2020-06-15 17:26:23 [urllib3.connectionpool] DEBUG: Starting new HTTPS connection (1): nominatim.openstreetmap.org:443
# 2020-06-15 17:26:23 [urllib3.connectionpool] DEBUG: https://nominatim.openstreetmap.org:443 "GET /search?q=Amsterdam+Airport+Schiphol&format=jsonv2&addressdetails=1&limit=1 HTTP/1.1" 200 None
# 2020-06-15 17:26:23 [geocoder.base] INFO: Requested https://nominatim.openstreetmap.org/search?q=Amsterdam+Airport+Schiphol&format=jsonv2&addressdetails=1&limit=1
#  24%|██▍       | 12/50 [00:05<00:20,  1.89it/s]2020-06-15 17:26:23 [urllib3.connectionpool] DEBUG: Starting new HTTPS connection (1): nominatim.openstreetmap.org:443
# 2020-06-15 17:26:24 [urllib3.connectionpool] DEBUG: https://nominatim.openstreetmap.org:443 "GET /search?q=Hong+Kong+International+Airport&format=jsonv2&addressdetails=1&limit=1 HTTP/1.1" 200 None
# 2020-06-15 17:26:24 [geocoder.base] INFO: Requested https://nominatim.openstreetmap.org/search?q=Hong+Kong+International+Airport&format=jsonv2&addressdetails=1&limit=1
#  26%|██▌       | 13/50 [00:06<00:17,  2.11it/s]2020-06-15 17:26:24 [urllib3.connectionpool] DEBUG: Starting new HTTPS connection (1): nominatim.openstreetmap.org:443
# 2020-06-15 17:26:24 [urllib3.connectionpool] DEBUG: https://nominatim.openstreetmap.org:443 "GET /search?q=Frankfurt+Airport&format=jsonv2&addressdetails=1&limit=1 HTTP/1.1" 200 None
# 2020-06-15 17:26:24 [geocoder.base] INFO: Requested https://nominatim.openstreetmap.org/search?q=Frankfurt+Airport&format=jsonv2&addressdetails=1&limit=1
#  28%|██▊       | 14/50 [00:06<00:18,  1.98it/s]2020-06-15 17:26:24 [urllib3.connectionpool] DEBUG: Starting new HTTPS connection (1): nominatim.openstreetmap.org:443
# 2020-06-15 17:26:25 [urllib3.connectionpool] DEBUG: https://nominatim.openstreetmap.org:443 "GET /search?q=Denver+International+Airport&format=jsonv2&addressdetails=1&limit=1 HTTP/1.1" 200 None
# 2020-06-15 17:26:25 [geocoder.base] INFO: Requested https://nominatim.openstreetmap.org/search?q=Denver+International+Airport&format=jsonv2&addressdetails=1&limit=1
#  30%|███       | 15/50 [00:07<00:17,  1.98it/s]2020-06-15 17:26:25 [urllib3.connectionpool] DEBUG: Starting new HTTPS connection (1): nominatim.openstreetmap.org:443
# 2020-06-15 17:26:25 [urllib3.connectionpool] DEBUG: https://nominatim.openstreetmap.org:443 "GET /search?q=Seoul+Incheon+International+Airport&format=jsonv2&addressdetails=1&limit=1 HTTP/1.1" 200 None
# 2020-06-15 17:26:25 [geocoder.base] INFO: Requested https://nominatim.openstreetmap.org/search?q=Seoul+Incheon+International+Airport&format=jsonv2&addressdetails=1&limit=1
#  32%|███▏      | 16/50 [00:07<00:17,  1.97it/s]2020-06-15 17:26:25 [urllib3.connectionpool] DEBUG: Starting new HTTPS connection (1): nominatim.openstreetmap.org:443
# 2020-06-15 17:26:26 [urllib3.connectionpool] DEBUG: https://nominatim.openstreetmap.org:443 "GET /search?q=Singapore+Changi+Airport&format=jsonv2&addressdetails=1&limit=1 HTTP/1.1" 200 None
# 2020-06-15 17:26:26 [geocoder.base] INFO: Requested https://nominatim.openstreetmap.org/search?q=Singapore+Changi+Airport&format=jsonv2&addressdetails=1&limit=1
#  34%|███▍      | 17/50 [00:08<00:16,  1.96it/s]2020-06-15 17:26:26 [urllib3.connectionpool] DEBUG: Starting new HTTPS connection (1): nominatim.openstreetmap.org:443
# 2020-06-15 17:26:26 [urllib3.connectionpool] DEBUG: https://nominatim.openstreetmap.org:443 "GET /search?q=Indira+Gandhi+International+Airport&format=jsonv2&addressdetails=1&limit=1 HTTP/1.1" 200 None
# 2020-06-15 17:26:26 [geocoder.base] INFO: Requested https://nominatim.openstreetmap.org/search?q=Indira+Gandhi+International+Airport&format=jsonv2&addressdetails=1&limit=1
#  36%|███▌      | 18/50 [00:08<00:15,  2.11it/s]2020-06-15 17:26:26 [urllib3.connectionpool] DEBUG: Starting new HTTPS connection (1): nominatim.openstreetmap.org:443
# 2020-06-15 17:26:27 [urllib3.connectionpool] DEBUG: https://nominatim.openstreetmap.org:443 "GET /search?q=Suvarnabhumi+Airport&format=jsonv2&addressdetails=1&limit=1 HTTP/1.1" 200 None
# 2020-06-15 17:26:27 [geocoder.base] INFO: Requested https://nominatim.openstreetmap.org/search?q=Suvarnabhumi+Airport&format=jsonv2&addressdetails=1&limit=1
#  38%|███▊      | 19/50 [00:09<00:15,  2.06it/s]2020-06-15 17:26:27 [urllib3.connectionpool] DEBUG: Starting new HTTPS connection (1): nominatim.openstreetmap.org:443
# 2020-06-15 17:26:27 [urllib3.connectionpool] DEBUG: https://nominatim.openstreetmap.org:443 "GET /search?q=Soekarno%E2%80%93Hatta+International+Airport&format=jsonv2&addressdetails=1&limit=1 HTTP/1.1" 200 None
# 2020-06-15 17:26:27 [geocoder.base] INFO: Requested https://nominatim.openstreetmap.org/search?q=Soekarno%E2%80%93Hatta+International+Airport&format=jsonv2&addressdetails=1&limit=1
#  40%|████      | 20/50 [00:09<00:15,  1.99it/s]2020-06-15 17:26:27 [urllib3.connectionpool] DEBUG: Starting new HTTPS connection (1): nominatim.openstreetmap.org:443
# 2020-06-15 17:26:28 [urllib3.connectionpool] DEBUG: https://nominatim.openstreetmap.org:443 "GET /search?q=John+F.+Kennedy+International+Airport&format=jsonv2&addressdetails=1&limit=1 HTTP/1.1" 200 None
# 2020-06-15 17:26:28 [geocoder.base] INFO: Requested https://nominatim.openstreetmap.org/search?q=John+F.+Kennedy+International+Airport&format=jsonv2&addressdetails=1&limit=1
#  42%|████▏     | 21/50 [00:10<00:15,  1.88it/s]2020-06-15 17:26:28 [urllib3.connectionpool] DEBUG: Starting new HTTPS connection (1): nominatim.openstreetmap.org:443
# 2020-06-15 17:26:28 [urllib3.connectionpool] DEBUG: https://nominatim.openstreetmap.org:443 "GET /search?q=Kuala+Lumpur+International+Airport&format=jsonv2&addressdetails=1&limit=1 HTTP/1.1" 200 None
# 2020-06-15 17:26:28 [geocoder.base] INFO: Requested https://nominatim.openstreetmap.org/search?q=Kuala+Lumpur+International+Airport&format=jsonv2&addressdetails=1&limit=1
#  44%|████▍     | 22/50 [00:10<00:13,  2.03it/s]2020-06-15 17:26:28 [urllib3.connectionpool] DEBUG: Starting new HTTPS connection (1): nominatim.openstreetmap.org:443
# 2020-06-15 17:26:29 [urllib3.connectionpool] DEBUG: https://nominatim.openstreetmap.org:443 "GET /search?q=Madrid+Barajas+Airport&format=jsonv2&addressdetails=1&limit=1 HTTP/1.1" 200 None
# 2020-06-15 17:26:29 [geocoder.base] INFO: Requested https://nominatim.openstreetmap.org/search?q=Madrid+Barajas+Airport&format=jsonv2&addressdetails=1&limit=1
#  46%|████▌     | 23/50 [00:11<00:13,  2.01it/s]2020-06-15 17:26:29 [urllib3.connectionpool] DEBUG: Starting new HTTPS connection (1): nominatim.openstreetmap.org:443
# 2020-06-15 17:26:29 [urllib3.connectionpool] DEBUG: https://nominatim.openstreetmap.org:443 "GET /search?q=San+Francisco+International+Airport&format=jsonv2&addressdetails=1&limit=1 HTTP/1.1" 200 None
# 2020-06-15 17:26:29 [geocoder.base] INFO: Requested https://nominatim.openstreetmap.org/search?q=San+Francisco+International+Airport&format=jsonv2&addressdetails=1&limit=1
#  48%|████▊     | 24/50 [00:11<00:12,  2.02it/s]2020-06-15 17:26:29 [urllib3.connectionpool] DEBUG: Starting new HTTPS connection (1): nominatim.openstreetmap.org:443
# 2020-06-15 17:26:30 [urllib3.connectionpool] DEBUG: https://nominatim.openstreetmap.org:443 "GET /search?q=Chengdu+Shuangliu+International+Airport&format=jsonv2&addressdetails=1&limit=1 HTTP/1.1" 200 None
# 2020-06-15 17:26:30 [geocoder.base] INFO: Requested https://nominatim.openstreetmap.org/search?q=Chengdu+Shuangliu+International+Airport&format=jsonv2&addressdetails=1&limit=1
#  50%|█████     | 25/50 [00:12<00:17,  1.42it/s]2020-06-15 17:26:30 [urllib3.connectionpool] DEBUG: Starting new HTTPS connection (1): nominatim.openstreetmap.org:443
# 2020-06-15 17:26:31 [urllib3.connectionpool] DEBUG: https://nominatim.openstreetmap.org:443 "GET /search?q=Shenzhen+Bao%27an+International+Airport&format=jsonv2&addressdetails=1&limit=1 HTTP/1.1" 200 None
# 2020-06-15 17:26:31 [geocoder.base] INFO: Requested https://nominatim.openstreetmap.org/search?q=Shenzhen+Bao%27an+International+Airport&format=jsonv2&addressdetails=1&limit=1
#  52%|█████▏    | 26/50 [00:13<00:16,  1.50it/s]2020-06-15 17:26:31 [urllib3.connectionpool] DEBUG: Starting new HTTPS connection (1): nominatim.openstreetmap.org:443
# 2020-06-15 17:26:31 [urllib3.connectionpool] DEBUG: https://nominatim.openstreetmap.org:443 "GET /search?q=Barcelona%E2%80%93El+Prat+Airport&format=jsonv2&addressdetails=1&limit=1 HTTP/1.1" 200 None
# 2020-06-15 17:26:31 [geocoder.base] INFO: Requested https://nominatim.openstreetmap.org/search?q=Barcelona%E2%80%93El+Prat+Airport&format=jsonv2&addressdetails=1&limit=1
#  54%|█████▍    | 27/50 [00:14<00:14,  1.61it/s]2020-06-15 17:26:31 [urllib3.connectionpool] DEBUG: Starting new HTTPS connection (1): nominatim.openstreetmap.org:443
# 2020-06-15 17:26:32 [urllib3.connectionpool] DEBUG: https://nominatim.openstreetmap.org:443 "GET /search?q=Istanbul+Airport&format=jsonv2&addressdetails=1&limit=1 HTTP/1.1" 200 None
# 2020-06-15 17:26:32 [geocoder.base] INFO: Requested https://nominatim.openstreetmap.org/search?q=Istanbul+Airport&format=jsonv2&addressdetails=1&limit=1
#  56%|█████▌    | 28/50 [00:14<00:12,  1.80it/s]2020-06-15 17:26:32 [urllib3.connectionpool] DEBUG: Starting new HTTPS connection (1): nominatim.openstreetmap.org:443
# 2020-06-15 17:26:32 [urllib3.connectionpool] DEBUG: https://nominatim.openstreetmap.org:443 "GET /search?q=Seattle-Tacoma+International+Airport&format=jsonv2&addressdetails=1&limit=1 HTTP/1.1" 200 None
# 2020-06-15 17:26:32 [geocoder.base] INFO: Requested https://nominatim.openstreetmap.org/search?q=Seattle-Tacoma+International+Airport&format=jsonv2&addressdetails=1&limit=1
#  58%|█████▊    | 29/50 [00:14<00:11,  1.86it/s]2020-06-15 17:26:32 [urllib3.connectionpool] DEBUG: Starting new HTTPS connection (1): nominatim.openstreetmap.org:443
# 2020-06-15 17:26:33 [urllib3.connectionpool] DEBUG: https://nominatim.openstreetmap.org:443 "GET /search?q=McCarran+International+Airport&format=jsonv2&addressdetails=1&limit=1 HTTP/1.1" 200 None
# 2020-06-15 17:26:33 [geocoder.base] INFO: Requested https://nominatim.openstreetmap.org/search?q=McCarran+International+Airport&format=jsonv2&addressdetails=1&limit=1
#  60%|██████    | 30/50 [00:15<00:10,  1.91it/s]2020-06-15 17:26:33 [urllib3.connectionpool] DEBUG: Starting new HTTPS connection (1): nominatim.openstreetmap.org:443
# 2020-06-15 17:26:33 [urllib3.connectionpool] DEBUG: https://nominatim.openstreetmap.org:443 "GET /search?q=Orlando+International+Airport&format=jsonv2&addressdetails=1&limit=1 HTTP/1.1" 200 None
# 2020-06-15 17:26:33 [geocoder.base] INFO: Requested https://nominatim.openstreetmap.org/search?q=Orlando+International+Airport&format=jsonv2&addressdetails=1&limit=1
#  62%|██████▏   | 31/50 [00:15<00:09,  1.93it/s]2020-06-15 17:26:33 [urllib3.connectionpool] DEBUG: Starting new HTTPS connection (1): nominatim.openstreetmap.org:443
# 2020-06-15 17:26:34 [urllib3.connectionpool] DEBUG: https://nominatim.openstreetmap.org:443 "GET /search?q=Toronto+Pearson+International+Airport&format=jsonv2&addressdetails=1&limit=1 HTTP/1.1" 200 None
# 2020-06-15 17:26:34 [geocoder.base] INFO: Requested https://nominatim.openstreetmap.org/search?q=Toronto+Pearson+International+Airport&format=jsonv2&addressdetails=1&limit=1
#  64%|██████▍   | 32/50 [00:16<00:09,  1.88it/s]2020-06-15 17:26:34 [urllib3.connectionpool] DEBUG: Starting new HTTPS connection (1): nominatim.openstreetmap.org:443
# 2020-06-15 17:26:34 [urllib3.connectionpool] DEBUG: https://nominatim.openstreetmap.org:443 "GET /search?q=Benito+Ju%C3%A1rez+International+Airport&format=jsonv2&addressdetails=1&limit=1 HTTP/1.1" 200 None
# 2020-06-15 17:26:34 [geocoder.base] INFO: Requested https://nominatim.openstreetmap.org/search?q=Benito+Ju%C3%A1rez+International+Airport&format=jsonv2&addressdetails=1&limit=1
#  66%|██████▌   | 33/50 [00:17<00:08,  1.90it/s]2020-06-15 17:26:34 [urllib3.connectionpool] DEBUG: Starting new HTTPS connection (1): nominatim.openstreetmap.org:443
# 2020-06-15 17:26:35 [urllib3.connectionpool] DEBUG: https://nominatim.openstreetmap.org:443 "GET /search?q=Charlotte+Douglas+International+Airport&format=jsonv2&addressdetails=1&limit=1 HTTP/1.1" 200 None
# 2020-06-15 17:26:35 [geocoder.base] INFO: Requested https://nominatim.openstreetmap.org/search?q=Charlotte+Douglas+International+Airport&format=jsonv2&addressdetails=1&limit=1
#  68%|██████▊   | 34/50 [00:17<00:08,  1.92it/s]2020-06-15 17:26:35 [urllib3.connectionpool] DEBUG: Starting new HTTPS connection (1): nominatim.openstreetmap.org:443
# 2020-06-15 17:26:35 [urllib3.connectionpool] DEBUG: https://nominatim.openstreetmap.org:443 "GET /search?q=Chhatrapati+Shivaji+Maharaj+International+Airport&format=jsonv2&addressdetails=1&limit=1 HTTP/1.1" 200 None
# 2020-06-15 17:26:35 [geocoder.base] INFO: Requested https://nominatim.openstreetmap.org/search?q=Chhatrapati+Shivaji+Maharaj+International+Airport&format=jsonv2&addressdetails=1&limit=1
#  70%|███████   | 35/50 [00:17<00:07,  2.04it/s]2020-06-15 17:26:35 [urllib3.connectionpool] DEBUG: Starting new HTTPS connection (1): nominatim.openstreetmap.org:443
# 2020-06-15 17:26:36 [urllib3.connectionpool] DEBUG: https://nominatim.openstreetmap.org:443 "GET /search?q=Taiwan+Taoyuan+International+Airport&format=jsonv2&addressdetails=1&limit=1 HTTP/1.1" 200 None
# 2020-06-15 17:26:36 [geocoder.base] INFO: Requested https://nominatim.openstreetmap.org/search?q=Taiwan+Taoyuan+International+Airport&format=jsonv2&addressdetails=1&limit=1
#  72%|███████▏  | 36/50 [00:18<00:07,  1.90it/s]2020-06-15 17:26:36 [urllib3.connectionpool] DEBUG: Starting new HTTPS connection (1): nominatim.openstreetmap.org:443
# 2020-06-15 17:26:36 [urllib3.connectionpool] DEBUG: https://nominatim.openstreetmap.org:443 "GET /search?q=Kunming+Changshui+International+Airport&format=jsonv2&addressdetails=1&limit=1 HTTP/1.1" 200 None
# 2020-06-15 17:26:36 [geocoder.base] INFO: Requested https://nominatim.openstreetmap.org/search?q=Kunming+Changshui+International+Airport&format=jsonv2&addressdetails=1&limit=1
#  74%|███████▍  | 37/50 [00:18<00:06,  2.05it/s]2020-06-15 17:26:36 [urllib3.connectionpool] DEBUG: Starting new HTTPS connection (1): nominatim.openstreetmap.org:443
# 2020-06-15 17:26:37 [urllib3.connectionpool] DEBUG: https://nominatim.openstreetmap.org:443 "GET /search?q=Munich+Airport&format=jsonv2&addressdetails=1&limit=1 HTTP/1.1" 200 None
# 2020-06-15 17:26:37 [geocoder.base] INFO: Requested https://nominatim.openstreetmap.org/search?q=Munich+Airport&format=jsonv2&addressdetails=1&limit=1
#  76%|███████▌  | 38/50 [00:19<00:06,  1.96it/s]2020-06-15 17:26:37 [urllib3.connectionpool] DEBUG: Starting new HTTPS connection (1): nominatim.openstreetmap.org:443
# 2020-06-15 17:26:37 [urllib3.connectionpool] DEBUG: https://nominatim.openstreetmap.org:443 "GET /search?q=Ninoy+Aquino+International+Airport&format=jsonv2&addressdetails=1&limit=1 HTTP/1.1" 200 None
# 2020-06-15 17:26:37 [geocoder.base] INFO: Requested https://nominatim.openstreetmap.org/search?q=Ninoy+Aquino+International+Airport&format=jsonv2&addressdetails=1&limit=1
#  78%|███████▊  | 39/50 [00:19<00:05,  2.01it/s]2020-06-15 17:26:37 [urllib3.connectionpool] DEBUG: Starting new HTTPS connection (1): nominatim.openstreetmap.org:443
# 2020-06-15 17:26:38 [urllib3.connectionpool] DEBUG: https://nominatim.openstreetmap.org:443 "GET /search?q=Xi%27an+Xianyang+International+Airport&format=jsonv2&addressdetails=1&limit=1 HTTP/1.1" 200 None
# 2020-06-15 17:26:38 [geocoder.base] INFO: Requested https://nominatim.openstreetmap.org/search?q=Xi%27an+Xianyang+International+Airport&format=jsonv2&addressdetails=1&limit=1
#  80%|████████  | 40/50 [00:20<00:05,  1.99it/s]2020-06-15 17:26:38 [urllib3.connectionpool] DEBUG: Starting new HTTPS connection (1): nominatim.openstreetmap.org:443
# 2020-06-15 17:26:38 [urllib3.connectionpool] DEBUG: https://nominatim.openstreetmap.org:443 "GET /search?q=London+Gatwick+Airport&format=jsonv2&addressdetails=1&limit=1 HTTP/1.1" 200 None
# 2020-06-15 17:26:38 [geocoder.base] INFO: Requested https://nominatim.openstreetmap.org/search?q=London+Gatwick+Airport&format=jsonv2&addressdetails=1&limit=1
#  82%|████████▏ | 41/50 [00:21<00:04,  1.97it/s]2020-06-15 17:26:38 [urllib3.connectionpool] DEBUG: Starting new HTTPS connection (1): nominatim.openstreetmap.org:443
# 2020-06-15 17:26:39 [urllib3.connectionpool] DEBUG: https://nominatim.openstreetmap.org:443 "GET /search?q=Newark+Liberty+International+Airport&format=jsonv2&addressdetails=1&limit=1 HTTP/1.1" 200 None
# 2020-06-15 17:26:39 [geocoder.base] INFO: Requested https://nominatim.openstreetmap.org/search?q=Newark+Liberty+International+Airport&format=jsonv2&addressdetails=1&limit=1
#  84%|████████▍ | 42/50 [00:21<00:04,  1.96it/s]2020-06-15 17:26:39 [urllib3.connectionpool] DEBUG: Starting new HTTPS connection (1): nominatim.openstreetmap.org:443
# 2020-06-15 17:26:39 [urllib3.connectionpool] DEBUG: https://nominatim.openstreetmap.org:443 "GET /search?q=Phoenix+Sky+Harbor+International+Airport&format=jsonv2&addressdetails=1&limit=1 HTTP/1.1" 200 None
# 2020-06-15 17:26:39 [geocoder.base] INFO: Requested https://nominatim.openstreetmap.org/search?q=Phoenix+Sky+Harbor+International+Airport&format=jsonv2&addressdetails=1&limit=1
#  86%|████████▌ | 43/50 [00:22<00:03,  1.98it/s]2020-06-15 17:26:39 [urllib3.connectionpool] DEBUG: Starting new HTTPS connection (1): nominatim.openstreetmap.org:443
# 2020-06-15 17:26:40 [urllib3.connectionpool] DEBUG: https://nominatim.openstreetmap.org:443 "GET /search?q=Sheremetyevo+International+Airport&format=jsonv2&addressdetails=1&limit=1 HTTP/1.1" 200 None
# 2020-06-15 17:26:40 [geocoder.base] INFO: Requested https://nominatim.openstreetmap.org/search?q=Sheremetyevo+International+Airport&format=jsonv2&addressdetails=1&limit=1
#  88%|████████▊ | 44/50 [00:22<00:03,  1.96it/s]2020-06-15 17:26:40 [urllib3.connectionpool] DEBUG: Starting new HTTPS connection (1): nominatim.openstreetmap.org:443
# 2020-06-15 17:26:40 [urllib3.connectionpool] DEBUG: https://nominatim.openstreetmap.org:443 "GET /search?q=Miami+International+Airport&format=jsonv2&addressdetails=1&limit=1 HTTP/1.1" 200 None
# 2020-06-15 17:26:40 [geocoder.base] INFO: Requested https://nominatim.openstreetmap.org/search?q=Miami+International+Airport&format=jsonv2&addressdetails=1&limit=1
#  90%|█████████ | 45/50 [00:23<00:02,  1.96it/s]2020-06-15 17:26:40 [urllib3.connectionpool] DEBUG: Starting new HTTPS connection (1): nominatim.openstreetmap.org:443
# 2020-06-15 17:26:41 [urllib3.connectionpool] DEBUG: https://nominatim.openstreetmap.org:443 "GET /search?q=Shanghai+Hongqiao+International+Airport&format=jsonv2&addressdetails=1&limit=1 HTTP/1.1" 200 None
# 2020-06-15 17:26:41 [geocoder.base] INFO: Requested https://nominatim.openstreetmap.org/search?q=Shanghai+Hongqiao+International+Airport&format=jsonv2&addressdetails=1&limit=1
#  92%|█████████▏| 46/50 [00:23<00:01,  2.11it/s]2020-06-15 17:26:41 [urllib3.connectionpool] DEBUG: Starting new HTTPS connection (1): nominatim.openstreetmap.org:443
# 2020-06-15 17:26:41 [urllib3.connectionpool] DEBUG: https://nominatim.openstreetmap.org:443 "GET /search?q=George+Bush+Intercontinental+Airport&format=jsonv2&addressdetails=1&limit=1 HTTP/1.1" 200 None
# 2020-06-15 17:26:41 [geocoder.base] INFO: Requested https://nominatim.openstreetmap.org/search?q=George+Bush+Intercontinental+Airport&format=jsonv2&addressdetails=1&limit=1
# 2020-06-15 17:26:41 [urllib3.connectionpool] DEBUG: Starting new HTTPS connection (1): nominatim.openstreetmap.org:443
# 2020-06-15 17:26:42 [urllib3.connectionpool] DEBUG: https://nominatim.openstreetmap.org:443 "GET /search?q=United+States&format=jsonv2&addressdetails=1&limit=1 HTTP/1.1" 200 None
# 2020-06-15 17:26:42 [geocoder.base] INFO: Requested https://nominatim.openstreetmap.org/search?q=United+States&format=jsonv2&addressdetails=1&limit=1
# 2020-06-15 17:26:42 [py.warnings] WARNING: /Users/raghulkrishna/opt/anaconda3/envs/scrapy/lib/python3.6/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#
# 2020-06-15 17:26:42 [py.warnings] WARNING: /Users/raghulkrishna/opt/anaconda3/envs/scrapy/lib/python3.6/site-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
#
#  94%|█████████▍| 47/50 [00:24<00:01,  1.55it/s]2020-06-15 17:26:42 [urllib3.connectionpool] DEBUG: Starting new HTTPS connection (1): nominatim.openstreetmap.org:443
# 2020-06-15 17:26:42 [urllib3.connectionpool] DEBUG: https://nominatim.openstreetmap.org:443 "GET /search?q=Chongqing+Jiangbei+International+Airport&format=jsonv2&addressdetails=1&limit=1 HTTP/1.1" 200 None
# 2020-06-15 17:26:42 [geocoder.base] INFO: Requested https://nominatim.openstreetmap.org/search?q=Chongqing+Jiangbei+International+Airport&format=jsonv2&addressdetails=1&limit=1
#  96%|█████████▌| 48/50 [00:24<00:01,  1.66it/s]2020-06-15 17:26:42 [urllib3.connectionpool] DEBUG: Starting new HTTPS connection (1): nominatim.openstreetmap.org:443
# 2020-06-15 17:26:43 [urllib3.connectionpool] DEBUG: https://nominatim.openstreetmap.org:443 "GET /search?q=Sydney+Airport&format=jsonv2&addressdetails=1&limit=1 HTTP/1.1" 200 None
# 2020-06-15 17:26:43 [geocoder.base] INFO: Requested https://nominatim.openstreetmap.org/search?q=Sydney+Airport&format=jsonv2&addressdetails=1&limit=1
#  98%|█████████▊| 49/50 [00:25<00:00,  1.74it/s]2020-06-15 17:26:43 [urllib3.connectionpool] DEBUG: Starting new HTTPS connection (1): nominatim.openstreetmap.org:443
# 2020-06-15 17:26:43 [urllib3.connectionpool] DEBUG: https://nominatim.openstreetmap.org:443 "GET /search?q=Leonardo+da+Vinci%E2%80%93Fiumicino+Airport&format=jsonv2&addressdetails=1&limit=1 HTTP/1.1" 200 None
# 2020-06-15 17:26:43 [geocoder.base] INFO: Requested https://nominatim.openstreetmap.org/search?q=Leonardo+da+Vinci%E2%80%93Fiumicino+Airport&format=jsonv2&addressdetails=1&limit=1
# 2020-06-15 17:26:43 [urllib3.connectionpool] DEBUG: Starting new HTTPS connection (1): nominatim.openstreetmap.org:443
# 2020-06-15 17:26:44 [urllib3.connectionpool] DEBUG: https://nominatim.openstreetmap.org:443 "GET /search?q=Italy&format=jsonv2&addressdetails=1&limit=1 HTTP/1.1" 200 None
# 2020-06-15 17:26:44 [geocoder.base] INFO: Requested https://nominatim.openstreetmap.org/search?q=Italy&format=jsonv2&addressdetails=1&limit=1
# 100%|██████████| 50/50 [00:26<00:00,  1.88it/s]

# %%
df3.head()
# Out:
#                 Country                                           Airport  \
# 0         United States  Hartsfield–Jackson Atlanta International Airport
# 1                 China             Beijing Capital International Airport
# 2         United States                 Los Angeles International Airport
# 3                 Japan                                    Haneda Airport
# 4  United Arab Emirates                       Dubai International Airport
#
#       location no_of_passengers        lat         lon
# 0      Atlanta      107,394,029  33.637799  -84.429271
# 1     Chaoyang      100,983,290  40.079285  116.594561
# 2      Garhoud       89,149,387  33.942168 -118.421376
# 3  Los Angeles       87,534,384  35.545721  139.780587
# 4          Ōta       87,131,973  25.251417   55.368541

# %%
#check for null values
df3.isna().sum()
# Out:
# Country             0
# Airport             0
# location            0
# no_of_passengers    0
# lat                 0
# lon                 0
# dtype: int64

# %%
df3.dtypes
# Out:
# Country              object
# Airport              object
# location             object
# no_of_passengers     object
# lat                 float64
# lon                 float64
# dtype: object

# %%
#change the datatype to integere
df3['no_of_passengers'] = df3['no_of_passengers'].str.replace(',', '').astype(int)

# %%
df3.dtypes
# Out:
# Country              object
# Airport              object
# location             object
# no_of_passengers      int64
# lat                 float64
# lon                 float64
# dtype: object

# %%
passengers = df3['no_of_passengers']/1000

# %%
passengers[0:5]
# Out:
# 0    107394.029
# 1    100983.290
# 2     89149.387
# 3     87534.384
# 4     87131.973
# Name: no_of_passengers, dtype: float64

# %%
#getting the lattitude longitude values with number of passengers
lat_lon_no= []
for i in range(df3.shape[0]):
    lat_lon_no.append([df3['lat'][i],df3['lon'][i],passengers[i]])

# %%
import folium
map_heatmap = folium.Map([40, -99], tiles='CartoDB Positron', zoom_start=4)

from folium import plugins
plugins.HeatMap(lat_lon_no).add_to(map_heatmap)
map_heatmap.save('map_busiest_heatmap.html')


map_heatmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
